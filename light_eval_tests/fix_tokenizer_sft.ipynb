# %%
import pathlib
import os
import shutil

# %%
path = pathlib.Path("/network/scratch/g/gagnonju/marglicot_saves/sft_saves/")

for file_path in path.glob("*/*/forward_tokenizer/*"):
    input_path = file_path
    print(input_path)
    
    output_path = file_path.parent.parent / "model" / file_path.name
    print(output_path)
    print()

    assert output_path.parent.exists(), output_path.parent
    # assert not output_path.exists()
    shutil.copy(input_path, output_path)
# Out:
# /network/scratch/g/gagnonju/marglicot_saves/sft_saves/cot_gsm8k_smollm2_1.7B-2025-03-09_22-25-33/0/forward_tokenizer/tokenizer_config.json
# /network/scratch/g/gagnonju/marglicot_saves/sft_saves/cot_gsm8k_smollm2_1.7B-2025-03-09_22-25-33/0/model/tokenizer_config.json
#
# /network/scratch/g/gagnonju/marglicot_saves/sft_saves/cot_gsm8k_smollm2_1.7B-2025-03-09_22-25-33/0/forward_tokenizer/special_tokens_map.json
# /network/scratch/g/gagnonju/marglicot_saves/sft_saves/cot_gsm8k_smollm2_1.7B-2025-03-09_22-25-33/0/model/special_tokens_map.json
#
# /network/scratch/g/gagnonju/marglicot_saves/sft_saves/cot_gsm8k_smollm2_1.7B-2025-03-09_22-25-33/0/forward_tokenizer/vocab.json
# /network/scratch/g/gagnonju/marglicot_saves/sft_saves/cot_gsm8k_smollm2_1.7B-2025-03-09_22-25-33/0/model/vocab.json
#
# /network/scratch/g/gagnonju/marglicot_saves/sft_saves/cot_gsm8k_smollm2_1.7B-2025-03-09_22-25-33/0/forward_tokenizer/merges.txt
# ...
