# %%
import pathlib
import rich

# %%
saves_root = pathlib.Path("~/scratch/rejection_sampling_saves").expanduser()
rich.print(list(saves_root.iterdir()))

rich.print(list(saves_root.glob("**/*.parquet")))
# Out:
# [
#     PosixPath('/home/mila/g/gagnonju/scratch/rejection_sampling_saves/gsm8k_0'),
#     PosixPath('/home/mila/g/gagnonju/scratch/rejection_sampling_saves/gsm8k_8')
# ]
# []
