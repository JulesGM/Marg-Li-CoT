# %%
import torch
import transformers as tr
from pathlib import Path
import more_itertools as mit

# %%
p = Path("~/scratch/rejection_sampling_saves/gsm8k_0/2025-03-24_01-32-35/epoch_0").expanduser()

new = tr.AutoModelForCausalLM.from_pretrained(p)
old = tr.AutoModelForCausalLM.from_pretrained("HuggingfaceTB/SmolLM2-1.7B-instruct")
