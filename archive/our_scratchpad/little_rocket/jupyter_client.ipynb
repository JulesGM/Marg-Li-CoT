# %%
import sys
print(sys.executable)
import torch
import main

# %matplotlib inline

import matplotlib 

print(f"{matplotlib.get_backend() = }")
print("Starting")
# Out:
# /Users/jules/.anaconda3/bin/python
# matplotlib.get_backend() = 'module://matplotlib_inline.backend_inline'
# Starting

# %%
# !rm -rf ./saves/*
main.main()
# Out:
# {
#     'device': 'cpu',
#     'sim_name': 'LunarLander-v2',
#     'epochs': 1000000,
#     'steps_between_updates': 8,
#     'qty_memory_samples': 64,
#     'step_size': 1,
#     'learning_rate': 1e-05,
#     'hidden_size': 64,
#     'num_layers': 3,
#     'tau': 0.001,
#     'lambda_': 0.99,
#     'gamma': 0.99,
#     'do_plot': True,
#     'num_rollouts_demo': 5,
#     'demo_every_n_seconds': 60,
#     'disable_demo': True,
#     'approach_name': <ApproachType.SARSA: 'sarsa'>,
#     'seed': 42
# }
#   0%|          | 2246/1000000 [27:52<206:22:17,  1.34it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/g8/9jpcpxwx71n97rcm4sr2r4300000gn/T/ipykernel_17953/2912621798.py in <module>
#       1 get_ipython().system('rm -rf ./saves/*')
# ----> 2 main.main()
#
# ...
